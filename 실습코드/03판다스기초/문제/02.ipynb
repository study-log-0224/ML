# %%
import pandas as pd
menu = pd.Series(['비빔밥', '김치찌개', '된장찌개'])
price = pd.Series([10000, 9000, 8000])

df = pd.DataFrame({'메뉴': menu, '가격': price})
df
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
df.to_csv('menu.csv', index=False)   # index=False: 행번호 저장 안 함(제출 파일 기본)

# %%
df2 = pd.read_csv('02.csv')        # 파일 → DataFrame
df2
# Out:
#        그룹  진료년도  성별      연령     진료인원
# 0     그룹1  2020  남자    0~4세     3297
# 1     그룹1  2020  남자    5-9세      113
# 2     그룹1  2020  남자  10-14세      127
# 3     그룹1  2020  남자  15-19세      210
# 4     그룹1  2020  남자  20-24세      269
# ...   ...   ...  ..     ...      ...
# 1615  그룹9  2024  여자  65-69세  1055865
# 1616  그룹9  2024  여자  70-74세   744011
# 1617  그룹9  2024  여자  75-79세   573405
# 1618  그룹9  2024  여자  80~84세   442064
# 1619  그룹9  2024  여자   85세이상   319378
#
# [1620 rows x 5 columns]

# %%
#print('모양:', df2.shape)
#print('열 이름:', df2.columns.tolist())
#print('결측치:', df2.isnull().sum().to_dict())
#print(df2['성별'].value_counts())   # 범주별 개수(타겟 분포 확인의 핵심)
#print(df2.describe())                 # 수치열 요약
df2.info()                            # 열별 타입·결측
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1620 entries, 0 to 1619
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   그룹      1620 non-null   object
#  1   진료년도    1620 non-null   int64
#  2   성별      1620 non-null   object
#  3   연령      1620 non-null   object
#  4   진료인원    1620 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 63.4+ KB

# %%
import numpy as np
df3 = pd.DataFrame({'가격': [10000, np.nan, 8000], '원산지': ['국내산', None, '국내산']})
df3
# Out:
#         가격   원산지
# 0  10000.0   국내산
# 1      NaN  None
# 2   8000.0   국내산

# %%
#print(df3['가격'].median())
#print(df3['원산지'].mode()[0])
#df3['가격']  = df3['가격'].fillna(df3['가격'].median())       # 수치 → 중앙값
#df3['원산지'] = df3['원산지'].fillna(df3['원산지'].mode()[0])   # 범주 → 최빈값
#df3
# Out:
# 국내산

# %%
grade = pd.Series(['합격', '불합격', '합격'])
grade
# Out:
# 0     합격
# 1    불합격
# 2     합격
# dtype: object

# %%
grade.map({'합격': 1, '불합격': 0})   # 글자 라벨 → 숫자(04 타겟 0/1 변환) → [1, 0, 1]
# Out:
# 0    1
# 1    0
# 2    1
# dtype: int64

# %%
pd.get_dummies(df2)
# Out:
#       진료년도  그룹_그룹1  그룹_그룹2  그룹_그룹3  그룹_그룹4  그룹_그룹5  그룹_그룹6  그룹_그룹7  그룹_그룹8  \
# 0     2020    True   False   False   False   False   False   False   False
# 1     2020    True   False   False   False   False   False   False   False
# 2     2020    True   False   False   False   False   False   False   False
# 3     2020    True   False   False   False   False   False   False   False
# 4     2020    True   False   False   False   False   False   False   False
# ...    ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1615  2024   False   False   False   False   False   False   False   False
# 1616  2024   False   False   False   False   False   False   False   False
# 1617  2024   False   False   False   False   False   False   False   False
# 1618  2024   False   False   False   False   False   False   False   False
# 1619  2024   False   False   False   False   False   False   False   False
#
#       그룹_그룹9  ...  진료인원_989  진료인원_99  진료인원_990002  진료인원_990925  진료인원_9913  \
# 0      False  ...     False    False        False        False      False
# 1      False  ...     False    False        False        False      False
# 2      False  ...     False    False        False        False      False
# 3      False  ...     False    False        False        False      False
# 4      False  ...     False    False        False        False      False
# ...      ...  ...       ...      ...          ...          ...        ...
# 1615    True  ...     False    False        False        False      False
# 1616    True  ...     False    False        False        False      False
# 1617    True  ...     False    False        False        False      False
# 1618    True  ...     False    False        False        False      False
# 1619    True  ...     False    False        False        False      False
#
#       진료인원_9915  진료인원_9929  진료인원_9956  진료인원_999  진료인원_9998
# 0         False      False      False     False      False
# 1         False      False      False     False      False
# 2         False      False      False     False      False
# 3         False      False      False     False      False
# 4         False      False      False     False      False
# ...         ...        ...        ...       ...        ...
# 1615      False      False      False     False      False
# 1616      False      False      False     False      False
# 1617      False      False      False     False      False
# 1618      False      False      False     False      False
# 1619      False      False      False     False      False
#
# [1620 rows x 1542 columns]

# %%
df2.head(1)
# Out:
#     그룹  진료년도  성별    연령  진료인원
# 0  그룹1  2020  남자  0~4세  3297

# %%
df2.tail(1)
# Out:
#        그룹  진료년도  성별     연령    진료인원
# 1619  그룹9  2024  여자  85세이상  319378

# %%
pd.concat([df2.head(1), df2.tail(1)], axis=0)   # 위아래로 이어붙이기(train+test)
# Out:
#        그룹  진료년도  성별     연령    진료인원
# 0     그룹1  2020  남자   0~4세    3297
# 1619  그룹9  2024  여자  85세이상  319378

# %%
df5 = pd.DataFrame({
    '메뉴':  ['비빔밥', '김치찌개', '된장찌개', '오무라이스', '초밥', '라멘', '돈까스'],
    '타입': ['한식','한식','한식','양식','일식','일식','양식'],
    '가격':  [10000, 9000, 8000, 5000, 6000, 7000, 8000],
    '원산지': ['국내산', '국내산', '국내산', '국내산', '국내산', '국내산', '국내산']
})

df5.groupby('타입')['가격'].mean()             # 그룹별 집계(EDA·작업형1)
# Out:
# 타입
# 양식    6500.0
# 일식    6500.0
# 한식    9000.0
# Name: 가격, dtype: float64
