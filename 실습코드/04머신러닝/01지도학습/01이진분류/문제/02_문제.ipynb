# %% [markdown]
# # 04 문제 2 (공공데이터) - Titanic 생존 예측
#
# ## 데이터 (공공데이터, 로그인 불필요)
# 타이타닉 탑승객 데이터. 아래 URL로 바로 로드된다(회원가입/API키 불필요).
# ```python
# import pandas as pd
# url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
# df = pd.read_csv(url)
# ```
# - 타겟: `Survived` (0=사망, 1=생존) -> 이진분류
# - 주요 특성: `Pclass`(객실등급), `Sex`(성별), `Age`(나이), `SibSp`, `Parch`, `Fare`(요금), `Embarked`(탑승항구)
#
# ## 문제
# 04에서 배운 워크플로우를 **이 새로운 데이터에 스스로 적용**하라.
#
# 1. 데이터를 로드하고 `Survived`의 분포와 결측치(`Age`, `Embarked`)를 확인하라.
# 2. 핵심 특성만 선택하고(이름/티켓/객실번호 등 제외), 결측치를 채운 뒤 원핫 인코딩하라.
# 3. 학습/검증으로 분할(`stratify` 사용)하고 랜덤포레스트로 학습하라.
# 4. 정확도와 ROC-AUC를 출력하라. (목표: 정확도 ~0.79, ROC-AUC ~0.82)
# 5. **(생각해보기)** 중요 특성 상위 3개는 무엇이며, '여성/상류층 생존율이 높다'는 역사적 사실과 어떻게 연결되는가?
#
# ## 제출
# - 위 과정을 담은 노트북 1개.
#
# ## 정답/해설
# - 정답 노트북: 정답.ipynb (같은 폴더) · 해설: [정답_해설.md](정답_해설.md)
